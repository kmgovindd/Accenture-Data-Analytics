# %% [markdown]
# ACCENTURE - DATA ANALYTICS PROJECT
#
# Author: Govind K M
# Mail Id: kmgovindd@gmail.com
# github: https://github.com/kmgovindd

# %% [markdown]
# # **Task 2: Data Cleaning & Modeling**

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as plio
plio.templates
import numpy as np

# %%
df1 = pd.read_csv('Content.csv')
df2 = pd.read_csv('ReactionTypes.csv')
df3 = pd.read_csv('Reactions.csv')

# %% [markdown]
# From here on,
# df1 = content
# df2 = ReactionTypes
# df3 = Reactions

# %%
df1.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %% [markdown]
# **Visualization**

# %%
_df_4.groupby('Category').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_20.groupby('Content ID').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df2.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
df3.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %% [markdown]
# **Dropping columns containing missing values**

# %%
df1.dropna(how='any')
df2.dropna(how='any')
df3.dropna(how='any')
# Out:
#        Unnamed: 0                            Content ID  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# ...

# %% [markdown]
# **Droping colums that are unnecessary (For example: URL, User ID )**

# %%
df1.drop(columns = ['URL', 'User ID'])
# Out:
#      Unnamed: 0                            Content ID   Type         Category
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2  photo         Studying
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo   healthy eating
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f  photo   healthy eating
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6  photo       technology
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180  video             food
# ..          ...                                   ...    ...              ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb  video  public speaking
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c    GIF       technology
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b  audio         veganism
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    GIF          culture
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56  audio       technology
#
# [1000 rows x 4 columns]

# %% [markdown]
# **Merging the dataset**

# %%
merged_reaction = pd.merge(df3, df2, on='Type')
merged_content = pd.merge(df1, merged_reaction , on='Content ID')

# %% [markdown]
# Content and reaction have been merged as "merged_content"

# %%
merged_content.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                               User ID_x Type_x  Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo  Studying
# 1  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo  Studying
# 2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo  Studying
# 3  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo  Studying
# 4  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo  Studying
#
#                                                  URL  Unnamed: 0_x  \
# 0  https://socialbuzz.cdn.com/content/storage/975...             1
# 1  https://socialbuzz.cdn.com/content/storage/975...             4
# 2  https://socialbuzz.cdn.com/content/storage/975...            35
# ...

# %%
merged_content.Type_x.value_counts()
# Out:
# photo    6589
# video    6245
# GIF      6079
# audio    5660
# Name: Type_x, dtype: int64

# %%
merged_content.to_csv('Cleaned Dataset.csv', index=False)
